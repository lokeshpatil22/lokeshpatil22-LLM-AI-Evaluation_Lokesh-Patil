# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#load csv data
iris=pd.read_csv("Iris.csv")
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris.shape   #shows 150 rows and 6 columns
# Out:
# (150, 6)

# %%
# Summary Statistics
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# Distribution analysis
sns.pairplot(iris, hue='Species')
plt.title('Pairplot of Iris Dataset')
plt.show()

# %%
# Correlation analysis
correlation_matrix = iris.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Iris Dataset')
plt.show()

# %% [markdown]
# ### Applying Linear Regression

# %% [markdown]
# #### Model-1

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
y=iris[['SepalLengthCm']]    #target variable

x=iris[['PetalLengthCm']]    #independent variable

# %%
from sklearn.model_selection import train_test_split

# %%
# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
# Creating and fitting the linear regression model
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Making predictions
y_pred = lr.predict(X_test)

# %%
y_test.head()           #actual values
# Out:
#      SepalLengthCm
# 73             6.1
# 18             5.7
# 118            7.7
# 78             6.0
# 76             6.8

# %%
y_pred[0:5]            #predicted values
# Out:
# array([[6.20359209],
#        [4.98685556],
#        [7.09586554],
#        [6.12247632],
#        [6.24414997]])

# %%
#finding the error in prediction

from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.12913567419731892

# %% [markdown]
# #### Model-2

# %%
y=iris[['SepalLengthCm']]    #target variable

x=iris[['SepalWidthCm']]    #independent variable

# %%
# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Creating and fitting the linear regression model
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Making predictions
y_pred = lr.predict(X_test)

# %%
y_test.head()      #actual values
# Out:
#      SepalLengthCm
# 73             6.1
# 18             5.7
# 118            7.7
# 78             6.0
# 76             6.8

# %%
y_pred[0:5]       #Predicted values
# Out:
# array([[5.85535232],
#        [5.67599057],
#        [5.89122467],
#        [5.83741614],
#        [5.85535232]])

# %%
#finding the error in prediction

mean_squared_error(y_test,y_pred)
# Out:
# 0.704743590100504

# %% [markdown]
# #### From the above two models we can say that the model-1 has better accuracy than model-2
